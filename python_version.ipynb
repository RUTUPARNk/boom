# %%
# !git clone https://github.com/RUTUPARNk/boom.git
# Out:
# Cloning into 'boom'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 55 (delta 17), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 18.01 KiB | 3.60 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !cd boom && export PYTHONPATH=$PYTHONPATH:$(pwd)/src && python -m src.cli run --config /content/boom/config/defaults.yaml
# Out:
# Running broad phase propagation for 100 satellites...
# Found 4950 candidate conjunctions in broad phase.
# /content/boom/src/sim/conjunction.py:29: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   result = minimize_scalar(distance_squared, bounds=(t0, t1), method='bounded', tol=tol_s)
# ALERT: S1-S2 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 1.85e-03
# ALERT: S1-S3 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 1.55e-03
# ALERT: S1-S4 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 2.65e-03
# ALERT: S1-S5 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 1.90e-03
# ALERT: S1-S6 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 1.85e-03
# ALERT: S1-S7 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 2.25e-03
# ALERT: S1-S8 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 2.30e-03
# ALERT: S1-S9 | TCA: 299.42418638235006 | Miss Dist: 0.0 m | Pc: 2.10e-03
# ...
